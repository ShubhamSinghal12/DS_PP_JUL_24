# %%
chr(212)
# Out:
# 'Ô'

# %%
max((1,2,3,4,5))
# Out:
# 5

# %%
ord?

# %%
# Functions

# %%
def kuch_bhi():
    print('KUCH BHI', 2 + 5)
    return 'Abhijeet'

# %%
print(kuch_bhi)
# Out:
# <function kuch_bhi at 0x000002BA34699700>

# %%
print(kuch_bhi())
# Out:
# KUCH BHI 7
# Abhijeet

# %%
def addition(var1, var2):
    print(var1 + var2)
    print(id(var1), id(var2))
    return var1 + var2

# %%
add_val = addition(10, 20)
# Out:
# 30
# 140732404930608 140732404930928

# %%
add_val
# Out:
# 30

# %%
a = 300
b = 350
print(id(a), id(b))
add_val = addition(a, b)
# Out:
# 2998767069616 2998767070704
# 650
# 2998767069616 2998767070704

# %%
def abhijeet():
    print(name)

# %%
print(abhijeet())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 print(abhijeet())
#
# Cell In[45], line 2, in abhijeet()
#       1 def abhijeet():
# ----> 2     print(name)
#
# NameError: name 'name' is not defined

# %%
def upper_lower(s):
    return chr(ord(s) + 32), chr(ord(s) + 32)

# %%
upper_lower('A')
# Out:
# ('a', 'a')

# %%
# Operands

# %%
# Algebreic Operators
print(1 + 2)
print(1 - 2)
print(1 * 2)
print(1 / 2)
# Out:
# 3
# -1
# 2
# 0.5

# %%
print(13 % 3)
# Out:
# 1

# %%
print(13 // 3)
# Out:
# 4

# %%
print(2 ** 3)
# Out:
# 8

# %%
# Logical Operators

# %%
print(5 < 2)
# Out:
# False

# %%
print(10 > 3)
# Out:
# True

# %%
a
# Out:
# 300

# %%
print(a == 300)
# Out:
# True

# %%
print(a != 500)
# Out:
# True

# %%
# Conditional Statements
# If
# Else
# Elif

# %%
var = 10

# %%
if (var <= 10):
    print('Lesser')
# Out:
# Lesser

# %%
if True:
    print('Hello')
# Out:
# Hello

# %%
if 1:
    print('Hi')
# Out:
# Hi

# %%
var = 20
if var == 20:
    print('Var = 20')
if var >= 15:
    print('Var = 15')
if var >= 10:
    print('Var = 10')
# Out:
# Var = 20
# Var = 15
# Var = 10

# %%
var = 100
if var == 20:
    print('Var = 20')
elif var >= 15:
    print('Var >= 15')
    
if var == 101:
    print('Var = 10')
else:
    print('Nothing')
# Out:
# Var >= 15
# Nothing

# %%
def reportcard(marks):
# marks = 82

    if marks > 90:
        return ('A+')
    elif marks > 80:
        return ('A')
    elif marks > 70:
        return ('B+')
    elif marks > 60:
        return ('B')
    elif marks > 50:
        return ('C+')
    elif marks > 40:
        return ('C')
    else:
        return ('F')

# %%
print(reportcard(52))
# Out:
# C+

# %%
def larger_num(a, b):
    if (a > b):
        return a
    else:
        return b

# %%
larger_num(10, 20)
# Out:
# 20

# %%
# and or

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
False and True
# Out:
# False

# %%
False and False
# Out:
# False

# %%
True or True
# Out:
# True

# %%
True or False
# Out:
# True

# %%
False or True
# Out:
# True

# %%
False or False
# Out:
# False

# %%
def print_largest(var1, var2, var3):
    if (var1 > var2 and var1 > var3):
        print(var1)
    elif (var2 > var1 and var2 > var3):
        print(var2)
    else:
        print(var3)

# %%
print_largest(10, 20, 65)
# Out:
# 65

# %%
# Loops

# %%
# For  --->  Iterables
# While---> Conditions

# %%
for i in range(5, 10, 2):
    print(i)
# Out:
# 5
# 7
# 9

# %%
for i in range(100, 9, -10):
    print(i)
# Out:
# 100
# 90
# 80
# 70
# 60
# 50
# 40
# 30
# 20
# 10

# %%
n = 3

for i in range(n):
    for j in range(n):
        print('* ', end = '')
    print()
# Out:
# * * *
# * * *
# * * *

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a = 50
print(id(a))
# Out:
# 140732404931888

# %%
id(50)
# Out:
# 140732404931888

# %%
b = 1000
a = b
