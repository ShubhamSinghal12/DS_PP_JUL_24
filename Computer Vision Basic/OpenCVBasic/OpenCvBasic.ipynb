# %%
import cv2
import matplotlib.pyplot as plt

# %%
cv2.__version__
# Out:
# '4.11.0'

# %%
img = cv2.imread("./dog.png")
# new_img = img[:,:,::-1]
new_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
print(img.shape)
# Out:
# (512, 512, 3)

# %%
plt.imshow(img)

# %%
plt.imshow(new_img)
