# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(-10,10,0.1)

# %%
def fn(x):
    return 2*x**2 - 3*x + 4

def detF(x):
    return 4*x-3

# %%
y = fn(x)

# %%
plt.plot(x,y)
plt.show()

# %%
xm = 8
lr = 0.6
pltXM = []
epochs = 100
for i in range(epochs):
    pltXM.append(xm)
    xm = xm - lr*detF(xm)
xm
# Out:
# 2972634914416180.5

# %%
plt.plot(x,y)
plt.plot(pltXM,fn(np.array(pltXM)))
plt.show()
