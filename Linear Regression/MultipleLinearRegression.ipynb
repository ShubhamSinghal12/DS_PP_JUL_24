# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.preprocessing import StandardScaler

# %%
data = pd.read_csv("./Training Data/BostonHousing.csv")
data.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
X = data.drop(['medv'],axis = 1).values
y = data['medv'].values

# %%
# X = (X - X.mean())/X.std()

# %%
# X = np.column_stack((X,np.ones(shape = (X.shape[0],1))))
# X.shape
# Out:
# (506, 14)

# %%
x_train,x_test,y_train,y_test = train_test_split(X,y,train_size=0.8)
std = StandardScaler()
x_train = std.fit_transform(x_train)
x_test = std.transform(x_test)
x_train.shape,x_test.shape
# Out:
# ((404, 13), (102, 13))

# %%
def hypothesis(x,th):
    # y_pred = np.zeros((x.shape[0],))
    # for i in range(len(x)):
    #     y_pred[i] = np.sum(x[i]*th)
    # return y_pred

    # return np.sum(x*th,axis = 1)

    return th@x.T

# %%
hypothesis(x_train,np.ones((X.shape[1],))).shape
# Out:
# (404,)

# %%
class LinearRegressionClassifier:
    def __init__(self,lr=0.01,epochs=1000):
        self.lr = lr
        self.epochs = epochs

    def fit(self,X,y):
        # self.th,self.errorGD = self.gradientDescent(X,y,self.lr,self.epochs)
        X = np.column_stack((X,np.ones(shape = (X.shape[0],1))))
        self.th = np.linalg.inv(X.T@X)@(X.T@y)

    def predict(self,t):
        t = np.column_stack((t,np.ones(shape = (t.shape[0],1))))
        return self.hypothesis(t,self.th)
        
    def hypothesis(self,x,th):
        # y_pred = np.zeros((x.shape[0],))
        # for i in range(len(x)):
        #     y_pred[i] = np.sum(x[i]*th)
        # return y_pred
    
        # return np.sum(x*th,axis = 1)
    
        return th@x.T
    
    def error(self,x,th,y):
        y_pred = self.hypothesis(x,th)
        return np.mean((y_pred-y)**2)
    
    def gradientDescent(self,x,y,lr=0.01,epochs = 1000):
        th = np.random.randn(x.shape[1])
        # print(th1,th0)
        errorGD = []
        for i in range(epochs+1):
            y_pred = self.hypothesis(x,th)
            # print(y_pred)
            #Gradient
            gradients = ((y_pred-y)@x)/x.shape[0]
            th = th - lr*gradients
    
            errorGD.append(error(x,th,y))
            # if i%1000 == 0:
            #     print(f"Epoch: {i+1}, Error: {errorGD[-1]}, r2 score{r2_score(y,y_pred)}")
            
            # print(th1,th0)
    
        return th,errorGD
    
    def r2_score(self,y_true,y_pred):
        rss = np.sum((y_true-y_pred)**2)
        tss = np.sum((y_true-np.mean(y_true))**2)
        return 1 - rss/tss

# %%
# th,errorGD = gradientDescent(X,y,lr = 0.1,epochs=100000)

# %%
clf = LinearRegressionClassifier(lr = 0.1,epochs=100000)
clf.fit(x_train,y_train)
clf.r2_score(y_train,clf.predict(x_train))
# Out:
# 0.7459438516723744

# %%
plt.plot(clf.errorGD)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[212], line 1
# ----> 1 plt.plot(clf.errorGD)
#       2 plt.show()
#
# AttributeError: 'LinearRegressionClassifier' object has no attribute 'errorGD'

# %%
clf.r2_score(y_test,clf.predict(x_test))
# Out:
# 0.7041904687301517

# %%
a = np.ones((2,))
b = np.eye(2)
b+a
# Out:
# array([[2., 1.],
#        [1., 2.]])

# %%
clf = LinearRegression()
clf.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
r2_score(y_train,clf.predict(x_train))
# Out:
# 0.7681471015732161

# %%
r2_score(y_test,clf.predict(x_test))
# Out:
# 0.6316156364339178
